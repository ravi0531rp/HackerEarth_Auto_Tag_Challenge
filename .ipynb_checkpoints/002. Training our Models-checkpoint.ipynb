# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf

import os
import sys
from glob import glob
import cv2 
import time
import datetime

from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense, Conv2D, Flatten
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.python.keras.applications.efficientnet import EfficientNetB0 as  PretrainedModel,preprocess_input

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
pwd
# Out:
# 'D:\\ALL_CODES_SECTIONWISE\\Z_ADD_ONS\\HACKATHONS_AND_COMPETITONS\\HACKEREARTH\\AUTO_TAG_IMAGE'

# %%
train_path = r"dataset\\classificationData\\ClassWiseSeparated\\TrainTestSet\\train"
test_path = r"dataset\\classificationData\\ClassWiseSeparated\\TrainTestSet\\test"

# %%
IMAGE_SIZE = [200,200]

# %%
image_files = glob(train_path + '/*/*.png')
test_image_files = glob(test_path + '/*/*.png')

folders = glob(train_path + "/*")

# %%
len(folders)
# Out:
# 4

# %% [markdown]
# ## EfficientNet-B0

# %%
ptm = PretrainedModel(
        input_shape = IMAGE_SIZE + [3],
        weights = 'imagenet',
        include_top = False

)

# %%
ptm

# %%
ptm.trainable = False
K = len(folders)

x = Flatten()(ptm.output)
x = Dense(K, activation = 'softmax')(x)

# %%
model = Model(inputs = ptm.input , outputs = x)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# rescaling (Rescaling)           (None, 200, 200, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 200, 200, 3)  7           rescaling[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 201, 201, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 100, 100, 32) 864         stem_conv_pad[0][0]
# ...

# %%
gen = ImageDataGenerator(
        rotation_range = 20,
        width_shift_range = 0.1,
        height_shift_range = 0.1,
        shear_range = 0.1,
        zoom_range = 0.2,
        horizontal_flip = True,
        preprocessing_function = preprocess_input
)

# %%
batch_size = 64

# %%
train_generator = gen.flow_from_directory(
            
    train_path,
    shuffle = True,
    target_size = IMAGE_SIZE,
    batch_size = batch_size
    )

test_generator = gen.flow_from_directory(
    
    test_path,
    target_size = IMAGE_SIZE,
    batch_size = batch_size
)
# Out:
# Found 8598 images belonging to 4 classes.
# Found 957 images belonging to 4 classes.

# %%
model.compile(loss = 'categorical_crossentropy' , optimizer = 'adam' , metrics = ['accuracy'])

# %%
model_name = r"EffNetB0_iter1" #input("Please provide a name for this model : ")
dir_name = r"Models\\" 

dir_name = dir_name + model_name + r"\\"
try:
    os.mkdir(dir_name)
    print("Created")
except:
    print("Already exists!!")
# Out:
# Created

# %%
acc_thresh = 0.98
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self,epoch,logs={}):
        if(logs.get('accuracy') > acc_thresh):
            print("Stopping training as desired accuracy reached....")
            self.model.stop_training = True

# %%
myCall = myCallback()

# %%
def sec2time(seconds):
    hours = seconds//3600
    minutes = (seconds%3600)//60
    seconds = (seconds%3600)%60
    return (hours, minutes, seconds)

# %%
start_time = time.time()
print(f"Started training the model at {datetime.datetime.now()}")
r = model.fit(
        train_generator,
        validation_data = test_generator,
        epochs = 20,
        steps_per_epoch = int(np.ceil(len(image_files)/batch_size)),
        validation_steps = int(np.ceil(len(test_image_files)/batch_size)),
        callbacks=[myCall]
)
end_time = time.time()
tot = end_time - start_time
hrs, mins , secs = sec2time(tot)
print(f"Total time taken is  {hrs} hours and {mins} minutes ")
# Out:
# Started training the model at 2021-10-15 18:56:06.352593
# Epoch 1/20
# 135/135 [==============================] - 415s 3s/step - loss: 1.8730 - accuracy: 0.6741 - val_loss: 1.5118 - val_accuracy: 0.7471
# Epoch 2/20
# 135/135 [==============================] - 327s 2s/step - loss: 1.5918 - accuracy: 0.7477 - val_loss: 2.1428 - val_accuracy: 0.7179
# Epoch 3/20
# 135/135 [==============================] - 326s 2s/step - loss: 1.5177 - accuracy: 0.7720 - val_loss: 1.6218 - val_accuracy: 0.7921
# Epoch 4/20
# 135/135 [==============================] - 340s 3s/step - loss: 1.2482 - accuracy: 0.8073 - val_loss: 1.7870 - val_accuracy: 0.7680
# Epoch 5/20
# 135/135 [==============================] - 346s 3s/step - loss: 1.1768 - accuracy: 0.8254 - val_loss: 1.9113 - val_accuracy: 0.7712
# Epoch 6/20
# 135/135 [==============================] - 344s 3s/step - loss: 1.2940 - accuracy: 0.8231 - val_loss: 1.8629 - val_accuracy: 0.7806
# Epoch 7/20
# ...

# %%
plt.plot(r.history['loss'] , color = 'red' , label = 'loss')
plt.plot(r.history['val_loss'] , color = 'blue' , label = 'val_loss')

# %%
plt.plot(r.history['accuracy'] , color = 'red' , label = 'loss')
plt.plot(r.history['val_accuracy'] , color = 'blue' , label = 'val_loss')

# %%
model.save(dir_name+model_name+".h5")

# %% [markdown]
# ### Observing for all our folders

# %%
save_path = r"dataset\\classificationData\\ClassWiseSeparated\\TrainTestSet\\" 

train_a_path = os.path.join(save_path , r"train\\A")
test_a_path = os.path.join(save_path , r"test\\A")

train_d_path = os.path.join(save_path , r"train\\D")
test_d_path = os.path.join(save_path , r"test\\D")

train_f_path = os.path.join(save_path , r"train\\F")
test_f_path = os.path.join(save_path , r"test\\F")

train_m_path = os.path.join(save_path , r"train\\M")
test_m_path = os.path.join(save_path , r"test\\M")

# %%
a_t_files = glob(test_a_path+"//*")
preds_a_t = []
for f in a_t_files:
    im = cv2.imread(f)
    im = cv2.resize(im,(200,200))
    im = im.reshape(1,200,200,3)
    preds_a_t.append(np.argmax(model.predict(im)))

# %%
print(f"Accuracy for class Attire is {np.mean(np.array(preds_a_t) == 0)}")
# Out:
# 0.852589641434263

# %%
d_t_files = glob(test_d_path+"//*")
preds_d_t = []
for f in d_t_files:
    im = cv2.imread(f)
    im = cv2.resize(im,(200,200))
    im = im.reshape(1,200,200,3)
    preds_d_t.append(np.argmax(model.predict(im)))

# %%
print(f"Accuracy for class Decorationandsignage is {np.mean(np.array(preds_d_t) == 1)}")
# Out:
# Accuracy for class Decorationandsignage is 0.7713004484304933

# %%
f_t_files = glob(test_f_path+"//*")
preds_f_t = []
for f in f_t_files:
    im = cv2.imread(f)
    im = cv2.resize(im,(200,200))
    im = im.reshape(1,200,200,3)
    preds_f_t.append(np.argmax(model.predict(im)))

# %%
print(f"Accuracy for class Food is {np.mean(np.array(preds_f_t) == 2)}")
# Out:
# Accuracy for class Food is 0.7192982456140351

# %%
m_t_files = glob(test_m_path+"//*")
preds_m_t = []
for f in m_t_files:
    im = cv2.imread(f)
    im = cv2.resize(im,(200,200))
    im = im.reshape(1,200,200,3)
    preds_m_t.append(np.argmax(model.predict(im)))

# %%
print(f"Accuracy for class misc is {np.mean(np.array(preds_m_t) == 3)}")
# Out:
# Accuracy for class misc is 0.6627450980392157

# %%
all_test_preds = []
all_test_preds.extend(preds_a_t)
all_test_preds.extend(preds_d_t)
all_test_preds.extend(preds_f_t)
all_test_preds.extend(preds_m_t)

# %%
len(all_test_preds)
# Out:
# 957

# %%
np.mean(np.array(all_test_preds) == test_generator.labels )
# Out:
# 0.7513061650992685

# %%
all_true_positives = 0
all_false_negatives = 0

# %%
for i in range(len(all_test_preds)):
    if np.array(all_test_preds)[i] == test_generator.labels[i]:
        all_true_positives +=1
    else:
        all_false_negatives +=1

# %%
all_true_positives
# Out:
# 719

# %%
all_false_negatives
# Out:
# 238

# %%
from sklearn.metrics import confusion_matrix

# %%
cf = confusion_matrix(test_generator.labels , all_test_preds )
cf
# Out:
# array([[214,   3,  17,  17],
#        [ 21, 172,  10,  20],
#        [ 25,  18, 164,  21],
#        [ 37,   9,  40, 169]], dtype=int64)

# %%
plt.matshow(cf)

# %% [markdown]
# ## EfficientNet-B7

# %%
from tensorflow.python.keras.applications.efficientnet import EfficientNetB7 as  PretrainedModel,preprocess_input

# %%
ptm = PretrainedModel(
        input_shape = IMAGE_SIZE + [3],
        weights = 'imagenet',
        include_top = False

)
ptm
# Out:
# ...
# 246292480/258076736 [===========================>..] - ETA: 0s
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# D:\Installed\Anaconda\envs\TweepGod\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     280                 read += len(block)
# --> 281                 tfp.write(block)
#     282                 blocknum += 1
#
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-84-4275782d1fed> in <module>
#       2         input_shape = IMAGE_SIZE + [3],
#       3         weights = 'imagenet',
# ----> 4         include_top = False
#       5
#       6 )
#
# ...

# %%
ptm.trainable = False
K = len(folders)

x = Flatten()(ptm.output)
x = Dense(K, activation = 'softmax')(x)

# %%
model = Model(inputs = ptm.input , outputs = x)
model.summary()

# %%
gen = ImageDataGenerator(
        rotation_range = 20,
        width_shift_range = 0.1,
        height_shift_range = 0.1,
        shear_range = 0.1,
        zoom_range = 0.2,
        horizontal_flip = True,
        preprocessing_function = preprocess_input
)

# %%
batch_size = 64
train_generator = gen.flow_from_directory(
            
    train_path,
    shuffle = True,
    target_size = IMAGE_SIZE,
    batch_size = batch_size
    )

test_generator = gen.flow_from_directory(
    
    test_path,
    target_size = IMAGE_SIZE,
    batch_size = batch_size
)

# %%
model.compile(loss = 'categorical_crossentropy' , optimizer = 'adam' , metrics = ['accuracy'])

# %%
model_name = r"EffNetB7_iter1" #input("Please provide a name for this model : ")
dir_name = r"Models\\" 

dir_name = dir_name + model_name + r"\\"
try:
    os.mkdir(dir_name)
    print("Created")
except:
    print("Already exists!!")

# %%
my_callbacks_all = [
    tf.keras.callbacks.ModelCheckpoint(filepath=dir_name + model_name + r"\\" + 'model.{epoch:02d}.h5'),
    myCall
]

# %%
start_time = time.time()
print(f"Started training the model at {datetime.datetime.now()}")
r = model.fit(
        train_generator,
        validation_data = test_generator,
        epochs = 20,
        steps_per_epoch = int(np.ceil(len(image_files)/batch_size)),
        validation_steps = int(np.ceil(len(test_image_files)/batch_size)),
        callbacks=my_callbacks_all
)
end_time = time.time()
tot = end_time - start_time
hrs, mins , secs = sec2time(tot)
print(f"Total time taken is  {hrs} hours and {mins} minutes ")
